# %%
import sys
print(sys.executable)
# Out:
# /opt/anaconda3/envs/myproj/bin/python

# %%
import kagglehub
print("kagglehub version:", kagglehub.__version__)
# Out:
# kagglehub version: 0.3.12

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("ak0212/china-cancer-patient-records")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /Users/f/.cache/kagglehub/datasets/ak0212/china-cancer-patient-records/versions/1

# %%
import os

data_dir = "/Users/f/.cache/kagglehub/datasets/ak0212/china-cancer-patient-records/versions/1"
print(os.listdir(data_dir))
# Out:
# ['china_cancer_patients_synthetic.csv']

# %%
import pandas as pd

df = pd.read_csv(f"{data_dir}/china_cancer_patients_synthetic.csv")

# %%
# Show unique tumor types
print("Unique tumor types:", df['TumorType'].unique())
print("Number of unique tumor types:", df['TumorType'].nunique())
# Out:
# Unique tumor types: ['Lung' 'Breast' 'Stomach' 'Liver' 'Colorectal' 'Cervical']
# Number of unique tumor types: 6

# %%
# Form (Zeilen, Spalten)
print("Shape:", df.shape)

# Erste 5 Zeilen
display(df.head())

# Datentypen & Nicht-Null-Zahlen
print(df.info())

# Grundlegende Statistik (numerisch + kategorisch)
display(df.describe(include="all"))
# Out:
# Shape: (10000, 20)
#    PatientID Gender  Age   Province Ethnicity TumorType CancerStage  \
# 0  CHN-00001   Male   32      Hunan       Han      Lung           I
# 1  CHN-00002   Male   66    Sichuan       Han      Lung          IV
# 2  CHN-00003  Other   26  Guangdong       Han      Lung         III
# 3  CHN-00004  Other   35      Anhui    Uyghur    Breast         III
# 4  CHN-00005   Male   32  Guangdong       Han   Stomach          II
#
#   DiagnosisDate  TumorSize Metastasis TreatmentType SurgeryDate  \
# 0    2010-07-24        8.2         No     Radiation  2010-08-24
# 1    2015-01-03        9.5        Yes  Chemotherapy  2015-03-24
# 2    2022-03-26        9.3        Yes       Surgery  2022-07-14
# 3    2019-06-19        7.7         No       Surgery  2019-08-27
# 4    2012-02-07        7.3         No  Chemotherapy         NaN
#
#    ChemotherapySessions  RadiationSessions SurvivalStatus  FollowUpMonths  \
# ...

# %%
import os

# Create a new folder for saving the data
output_dir = "./data"
os.makedirs(output_dir, exist_ok=True)

# Save the first 20 records to a CSV file
output_file = f"{output_dir}/first_20_records.csv"
df.head(20).to_csv(output_file, index=False)

print(f"First 20 records saved to: {output_file}")
# Out:
# First 20 records saved to: ./data/first_20_records.csv
